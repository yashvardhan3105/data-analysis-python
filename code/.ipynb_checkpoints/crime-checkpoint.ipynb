# %% [markdown]
# Installing Requirements

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install seaborn --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a Pandas DataFrame
data = pd.read_csv("../data/DataOfCrimesInIndiaAgainstWomen.csv") 

# Sorting Year and States Accordingly
data.sort_values(by=['Year', 'STATE/UT'], inplace=True)
data = data.fillna(0)

print(data)

# Plotting the line graph with '--' markers for showing the Trend of Total Crimes Over the Years
x = data.get("Year")
y = data.get("Total Crimes against Women")
sns.barplot(x=data['Year'], y=data['Total Crimes against Women'], data=data, errorbar=None)
plt.xlabel('Year')
plt.ylabel('Total Crimes Against Women')
plt.title('Trend of Total Crimes Against Women')
plt.xticks(rotation=45)
plt.show()


# Plotting a bar graph to show the trend of Literates over the Years.
x1 = data["Year"]
y1 = data['Literates - Females']  # Females as y1
y2 = data['Literates - Males']   # Males as y2
sns.barplot(x=x1, y=y2, label='Males', errorbar=None)
sns.barplot(x=x1, y=y1, label='Females', errorbar=None)
plt.ylim(0, max(y1))
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.xlabel('Year')
plt.ylabel('Number of Literates')
plt.title('Trend of Literates (Females and Males)')
plt.xticks(rotation=45)
plt.legend()
plt.show()




# Plotting a Year over Year Comparison
# Plot the year-over-year change for Rape
data['Year-over-Year Change'] = data['Rape'].pct_change() / 100
plt.plot(data['Year'][1:], data['Year-over-Year Change'][1:])  # Exclude the first year as it has no previous year to compare with
plt.xlabel('Year')
plt.ylabel('Year-over-Year Change (%)')
plt.title('Year-over-Year Change in Rape')
plt.ylim(0, 100)
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.show()


# Plotting Year Over Year Change for Kidnapping and Abduction
data['Year-over-Year Change'] = data['Kidnapping and Abduction'].pct_change() / 100
plt.plot(data['Year'][1:], data['Year-over-Year Change'][1:])  # Exclude the first year as it has no previous year to compare with
plt.xlabel('Year')
plt.ylabel('Year-over-Year Change (%)')
plt.title('Year-over-Year Change in Kiddnapping & Abduction')
plt.ylim(0, 100)
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.show()



# Plotting Year Over Year Change for Dowry Deaths
data['Year-over-Year Change'] = data['Dowry Deaths'].pct_change() / 100
plt.plot(data['Year'][1:], data['Year-over-Year Change'][1:])  # Exclude the first year as it has no previous year to compare with
plt.xlabel('Year')
plt.ylabel('Year-over-Year Change (%)')
plt.title('Year-over-Year Change in Dowry Deaths')
plt.ylim(0, 100)
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.show()


# Plotting Year Over Year Change for Insult to modesty of Women
data['Year-over-Year Change'] = data['Insult to modesty of Women'].pct_change() / 100
plt.plot(data['Year'][1:], data['Year-over-Year Change'][1:])  # Exclude the first year as it has no previous year to compare with
plt.xlabel('Year')
plt.ylabel('Year-over-Year Change (%)')
plt.title('Year-over-Year Change in Insult to modesty of Women')
plt.ylim(0, 100)
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.show()


# Plotting Year Over Year Change for Cruelty by Husband or his Relatives
data['Year-over-Year Change'] = data['Cruelty by Husband or his Relatives'].pct_change() / 100
plt.plot(data['Year'][1:], data['Year-over-Year Change'][1:])  # Exclude the first year as it has no previous year to compare with
plt.xlabel('Year')
plt.ylabel('Year-over-Year Change (%)')
plt.title('Year-over-Year Change in Cruelty by Husband or his Relatives')
plt.ylim(0, 100)
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.show()



# Plotting Year Over Year Change for Imporatation of Girls
data['Year-over-Year Change'] = data['Importation of Girls'].pct_change() / 100
plt.plot(data['Year'][1:], data['Year-over-Year Change'][1:])  # Exclude the first year as it has no previous year to compare with
plt.xlabel('Year')
plt.ylabel('Year-over-Year Change (%)')
plt.title('Year-over-Year Change in Importation of Girls')
plt.ylim(0, 100)
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.show()



# Plotting Year on Year Change for Total Crimes Against Women
data['Year-over-Year Change'] = data['Total Crimes against Women'].pct_change() / 1000
plt.plot(data['Year'][1:], data['Year-over-Year Change'][1:])  # Exclude the first year as it has no previous year to compare with
plt.xlabel('Year')
plt.ylabel('Year-over-Year Change (%)')
plt.title('Year-over-Year Change in Total Crimes against Women')
plt.ylim(0, 100)
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.show()




# Male VS Female
sex_ratio = (data['Population - Females'] / data['Population - Males'])
sns.barplot(x=data['Year'], y=sex_ratio, errorbar=None)
plt.xticks(rotation=45)
plt.ylabel('Sex Ratio')
plt.title('Sex Ratio Over the Years')
plt.ylim(0, 2)
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.show()



# Crime Rate Per Captia
total_population = data['Population - Males'] + data['Population - Females']
crime_rate_per_capita = (data['Total Crimes against Women'] / (total_population / 100000))
sns.barplot(x=data['Year'], y=crime_rate_per_capita, errorbar=None)
plt.xlabel('Year')
plt.ylabel('Crime Rate Per 1,000,000')
plt.title('Crime Rate Per Capita Against Women')
plt.xticks(rotation=45)
plt.show()


# Population Growth Rate 
population_growth_rate = (data['Population - Males']+data['Population - Females'])
sns.lineplot(x=data['Year'], y=population_growth_rate, errorbar=None )
plt.xlabel('Year')
plt.ylabel('Population Growth')
plt.title('Population Growth Over the Years')
plt.ylim(0, max(y1 + y2))
plt.gca().yaxis.set_major_formatter('{:,.0f}'.format)
plt.xticks(rotation=45)
plt.show()
# Out:
#                         STATE/UT  Year  Population  Literates - Males  \
# 14                ANDHRA PRADESH  2001    75728400           23444788
# 28             ARUNACHAL PRADESH  2001     1098328             303281
# 42                         ASSAM  2001    26638600            8188697
# 0    Andaman and Nicobar Islands  2001      356650             146831
# 56                         BIHAR  2001    82879910           20644376
# ..                           ...   ...         ...                ...
# 433                   TAMIL NADU  2014    72138958           28040491
# 447                      TRIPURA  2014     3671032            1501369
# 461                UTTAR PRADESH  2014   199581477           68234964
# 475                  UTTARAKHAND  2014    10116752            3863708
# 489                  WEST BENGAL  2014    91347736           33818810
#
#      Literates - Females  Population - Males  Population - Females  Year.1  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data into a Pandas DataFrame
data = pd.read_csv("../data/DataOfCrimesInIndiaAgainstWomen.csv") 

# Sorting Year and States Accordingly
data.sort_values(by=['Year', 'STATE/UT'], inplace=True)
data = data.fillna(0)

print(data)


rape = data['Rape']
kidnapping = data['Kidnapping and Abduction']
dowry_deaths = data['Dowry Deaths']
assault = data['Assault on women with intent to outrage her modesty']
insult = data['Insult to modesty of Women']
cruelty = data['Cruelty by Husband or his Relatives']
importation = data['Importation of Girls']

total_cases_in_india = data.unique['Total Crimes In India']


print(total_cases_in_india)
# Out:
#                         STATE/UT  Year  Population  Literates - Males  \
# 14                ANDHRA PRADESH  2001    75728400           23444788
# 28             ARUNACHAL PRADESH  2001     1098328             303281
# 42                         ASSAM  2001    26638600            8188697
# 0    Andaman and Nicobar Islands  2001      356650             146831
# 56                         BIHAR  2001    82879910           20644376
# ..                           ...   ...         ...                ...
# 433                   TAMIL NADU  2014    72138958           28040491
# 447                      TRIPURA  2014     3671032            1501369
# 461                UTTAR PRADESH  2014   199581477           68234964
# 475                  UTTARAKHAND  2014    10116752            3863708
# 489                  WEST BENGAL  2014    91347736           33818810
#
#      Literates - Females  Population - Males  Population - Females  Year.1  \
# ...
